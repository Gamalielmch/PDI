# %%
import sys 
import math 
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline

# %%
#img = plt.imread(r'C:\Users\Usuario\Documents\Python\bote.jpg')
img = plt.imread(r'C:\Users\Usuario\Documents\Python\im_contrast_2.tiff')
fig1=plt.figure(figsize = (8,8))
plt.imshow(img, cmap='gray',vmin=0,vmax=255)
plt.axis('off');

# %%
# img.shape
fig2 = plt.figure(figsize = (15,8))
a = fig2.add_subplot(1, 2, 1)
plt.imshow(img, cmap='gray',vmin=0,vmax=255)
plt.axis('off');
a.set_title('Original Image')
inmax = np.amax(img)
inmin = np.amin(img)
b = fig2.add_subplot(1, 2, 2)
b.set_title('Histogram')
arr = np.array(img)
arr = arr.ravel()
b, bins, patches = plt.hist(arr, 255)
plt.xlim([0,255])
plt.show()

# %%
c=255/(np.log(1+inmax));
img=img[:,:]+1
#print(img.dtype)
Iout=np.log(img)
Iout=c*Iout[:,:]
Iout=Iout.astype(np.uint8)
print(Iout.dtype)
fig3 = plt.figure(figsize = (15,8))
a = fig3.add_subplot(1, 2, 1)


print(Iout[100, 100])
plt.imshow(img, cmap='gray',vmin=0,vmax=255)
plt.axis('off');
a.set_title('Original Image')

b = fig3.add_subplot(1, 2, 2)
plt.imshow(Iout, cmap='gray',vmin=0,vmax=255)
plt.axis('off');
b.set_title('Improvement Image')
# Out:
# uint8
# 225
# Text(0.5, 1.0, 'Improvement Image')
